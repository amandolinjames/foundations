# %%
import pandas as pd
df= pd.read_csv("NYC_Wi-Fi_Hotspot_Locations_Map.csv")

# %%
#Who would you contact to ask more info?
#Contact the NYC Government
#https://opendata.cityofnewyork.us/engage/

# %%
df
# Out:
#       OBJECTID Borough          Type              Provider  \
# 0         1673      BK          Free                 NYCHA
# 1         2364      MN          Free      Transit Wireless
# 2         2258      MN          Free      Transit Wireless
# 3         3391      MN          Free  LinkNYC - Citybridge
# 4         3448      MN          Free  LinkNYC - Citybridge
# 5          968      MN          Free               Chelsea
# 6         3347      MN          Free  LinkNYC - Citybridge
# 7          959      MN          Free               Chelsea
# 8         3411      MN          Free  LinkNYC - Citybridge
# 9         3395      MN          Free  LinkNYC - Citybridge
# 10        2262      MN          Free      Transit Wireless
# 11         502      MN  Limited Free     Time Warner Cable
# 12        2275      MN          Free      Transit Wireless
# 13        3584      MN          Free  LinkNYC - Citybridge
# 14        3541      MN          Free  LinkNYC - Citybridge
# ...

# %%
df.head()
# Out:
#    OBJECTID Borough  Type              Provider  \
# 0      1673      BK  Free                 NYCHA
# 1      2364      MN  Free      Transit Wireless
# 2      2258      MN  Free      Transit Wireless
# 3      3391      MN  Free  LinkNYC - Citybridge
# 4      3448      MN  Free  LinkNYC - Citybridge
#
#                                                 Name  \
# 0                                                  0
# 1  Fulton St (J,M,Z,2,3,4,5)/Bway-Nassau St (A,C)...
# 2                                  28th Street - (6)
# 3                                       mn-05-121626
# 4                                       mn-05-139806
#
#                           Location   Latitude  Longitude              X  \
# 0              138 Cumberland Walk  40.694382 -73.974614  991289.588708
# 1      Fulton St (A,C,J,Z,2,3,4,5)  40.710368 -74.009509  981613.746661
# 2  28th Street - Park Avenue South  40.743070 -73.984264  988610.472216
# ...

# %%
df['Location_T'].count
# Out:
# <bound method Series.count of 0              Outdoor
# 1       Subway Station
# 2       Subway Station
# 3        Outdoor Kiosk
# 4        Outdoor Kiosk
# 5              Outdoor
# 6        Outdoor Kiosk
# 7              Outdoor
# 8        Outdoor Kiosk
# 9        Outdoor Kiosk
# 10      Subway Station
# 11             Outdoor
# 12      Subway Station
# 13       Outdoor Kiosk
# 14       Outdoor Kiosk
# 15       Outdoor Kiosk
# 16             Outdoor
# 17             Outdoor
# 18       Outdoor Kiosk
# 19       Outdoor Kiosk
# 20       Outdoor Kiosk
# 21       Outdoor Kiosk
# 22       Outdoor Kiosk
# 23       Outdoor Kiosk
# 24       Outdoor Kiosk
# 25       Outdoor Kiosk
# 26      Subway Station
# 27       Outdoor Kiosk
# 28       Outdoor Kiosk
# 29       Outdoor Kiosk
#              ...
# 2065           Outdoor
# 2066           Outdoor
# 2067           Outdoor
# 2068           Outdoor
# 2069           Outdoor
# 2070    Subway Station
# 2071     Outdoor Kiosk
# 2072           Outdoor
# ...

# %%
df['Location_T'].value_counts()
# Out:
# Outdoor               696
# Outdoor Kiosk         663
# Subway Station        276
# Library               214
# Indoor                125
# Outdoor TWC Aerial    121
# Name: Location_T, dtype: int64

# %%
# %matplotlib inline

# %%
df['Borough'].hist()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-dd217cd2b919> in <module>()
# ----> 1 df['Borough'].hist()
#
# /usr/local/lib/python3.6/site-packages/pandas/plotting/_core.py in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, **kwds)
#    2188         values = self.dropna().values
#    2189
# -> 2190         ax.hist(values, bins=bins, **kwds)
#    2191         ax.grid(grid)
#    2192         axes = np.array([ax])
#
# /usr/local/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# ...

# %%
#Map the locations of the Wifi

# %%
#Which borough has the most Wifi locations?

# %%
#What is the most common type of place to find Wifi? (Subway, outdoor kiosk, etc.)

# %%
#If you're in Brooklyn, how many wifi hotspots are near you?(within .5 mile)

# %%
#Make a heat map of wifi locations throughout the city
